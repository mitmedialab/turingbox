# %%
import requests

url = 'http://0.0.0.0:5000/api/v1/launch/'
payload =  {
            "user_id": "47",
            "data_id": "1",
            "model_id": "0",
            "job_id": "4747",
        }
headers = {'content-type': 'application/json'}

response = requests.post(url, data=json.dumps(payload), headers=headers)

# %%
response
# Out:
# <Response [405]>

# %%
response.text
# Out:
# '<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 3.2 Final//EN">\n<title>405 Method Not Allowed</title>\n<h1>Method Not Allowed</h1>\n<p>The method is not allowed for the requested URL.</p>\n'

# %%
r = requests.get(url)

# %%
import json
x = json.loads(r.text)

# %%
x['data']
# Out:
# [{'description': 'this is dummy data',
#   'id': '1',
#   'path': 'assets/data/data1.csv',
#   'title': 'data1',
#   'type': 'botsheet'},
#  {'description': 'swim10_front_non.jpg',
#   'id': 'db958fdba8db279f0475b2d2dacc24fd',
#   'path': 'assets/data/swim/swim10_front_non.jpg',
#   'title': 'Swim Suite Image 0',
#   'type': 'image'},
#  {'description': 'swim10_front_plus.jpg',
#   'id': '8211d03111038f055063ac4aa437c5de',
#   'path': 'assets/data/swim/swim10_front_plus.jpg',
#   'title': 'Swim Suite Image 1',
#   'type': 'image'},
#  {'description': 'swim11_front_non.jpg',
#   'id': '6dd681aa57b6ed95a46ed3ee63ef7488',
#   'path': 'assets/data/swim/swim11_front_non.jpg',
#   'title': 'Swim Suite Image 2',
#   'type': 'image'},
#  {'description': 'swim11_front_plus.jpg',
#   'id': '8e28b0d009c5a1d73cf7f5688d964a5e',
#   'path': 'assets/data/swim/swim11_front_plus.jpg',
#   'title': 'Swim Suite Image 3',
#   'type': 'image'},
#  {'description': 'swim12_front_non.jpg',
# ...

# %%
x['models']
# Out:
# [{'description': 'this is a dummy model',
#   'id': '1',
#   'path': 'assets/models/model1.py',
#   'title': 'model1'}]

# %%
r.text
# Out:
# '<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 3.2 Final//EN">\n<title>405 Method Not Allowed</title>\n<h1>Method Not Allowed</h1>\n<p>The method is not allowed for the requested URL.</p>\n'
